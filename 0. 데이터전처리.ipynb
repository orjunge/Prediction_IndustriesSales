# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
pd.set_option('display.max_columns', None)

import numpy as np

# %% [markdown]
# # 데이터로드: 6년치+구동+중분류 합치기

# %% [markdown]
# ## 데이터 로드

# %% [markdown]
# ### 자치구행정동

# %%
# 자치구행정동 상권코드 데이터 로드
seoul_gudong = pd.read_csv('/content/drive/MyDrive/MC_KDT/프로젝트/파이널프로젝트/데이터/상권코드_preprocessed.csv', encoding='utf-8')
seoul_gudong
# Out:
#           순번  자치구          행정동    상권_코드                     상권명  상권분류   면적(m²)
# 0        1.0  용산구        이태원1동  1001491                이태원 관광특구  관광특구   392647
# 1        2.0   중구          소공동  1001492  명동 남대문 북창동 다동 무교동 관광특구  관광특구   928278
# 2        3.0   중구          광희동  1001493            동대문패션타운 관광특구  관광특구   610708
# 3        4.0  종로구  종로1.2.3.4가동  1001494              종로·청계 관광특구  관광특구   635586
# 4        5.0  송파구          오륜동  1001495                 잠실 관광특구  관광특구  2334402
# ...      ...  ...          ...      ...                     ...   ...      ...
# 1666  1667.0  강동구         천호3동  2130322                고분다리전통시장  전통시장    31695
# 1667  1668.0  강동구         성내3동  2130323                 둔촌역전통시장  전통시장    36519
# 1668  1669.0  강동구           길동  2130324                 길동복조리시장  전통시장    29606
# 1669  1670.0  강동구         명일1동  2130325                  명일전통시장  전통시장    27660
# 1670  1671.0  강동구         고덕2동  2130326               고덕 골목형상점가  전통시장    29846
#
# [1671 rows x 7 columns]

# %% [markdown]
# ### 업종정보

# %%
# 업종 정보 데이터 로드
category = pd.read_excel('/content/drive/MyDrive/MC_KDT/프로젝트/파이널프로젝트/데이터/업종코드_중분류.xlsx')
category
# Out:
#    대분류      중분류     업종명  Unnamed: 3  Unnamed: 4
# 0   외식      식사류   한식음식점         NaN         NaN
# 1   외식      식사류   중식음식점         NaN         NaN
# 2   외식      식사류   일식음식점         NaN         NaN
# 3   외식      식사류   양식음식점         NaN         NaN
# 4   외식  카페/베이커리     제과점         NaN         NaN
# ..  ..      ...     ...         ...         ...
# 94  소매  가구/인테리어    인테리어         NaN         NaN
# 95  소매  가구/인테리어    조명용품         NaN         NaN
# 96  소매  가구/인테리어     예술품         NaN         NaN
# 97  소매       주유     주유소         NaN         NaN
# 98  소매       유통  전자상거래업         NaN         NaN
#
# [99 rows x 5 columns]

# %% [markdown]
# ### 매출_상권

# %%
# 매출 데이터 로드
sales_2022 = pd.read_csv('/content/drive/MyDrive/MC_KDT/프로젝트/파이널프로젝트/데이터/서울시 상권분석서비스(상권-추정매출)_2022년.csv', encoding='cp949')
sales_2021 = pd.read_csv('/content/drive/MyDrive/MC_KDT/프로젝트/파이널프로젝트/데이터/서울시_우리마을가게_상권분석서비스(신_상권_추정매출)_2021년.csv', encoding='cp949')
sales_2020 = pd.read_csv('/content/drive/MyDrive/MC_KDT/프로젝트/파이널프로젝트/데이터/서울시_우리마을가게_상권분석서비스(신_상권_추정매출)_2020년.csv', encoding='cp949')
sales_2019 = pd.read_csv('/content/drive/MyDrive/MC_KDT/프로젝트/파이널프로젝트/데이터/서울시_우리마을가게_상권분석서비스(신_상권_추정매출)_2019년.csv', encoding='cp949')
sales_2018 = pd.read_csv('/content/drive/MyDrive/MC_KDT/프로젝트/파이널프로젝트/데이터/서울시_우리마을가게_상권분석서비스(신_상권_추정매출)_2018년.csv', encoding = 'cp949')
sales_2017 = pd.read_csv('/content/drive/MyDrive/MC_KDT/프로젝트/파이널프로젝트/데이터/서울시_우리마을가게_상권분석서비스(신_상권_추정매출)_2017년.csv', encoding = 'cp949')

# %%
# 매출 데이터 로드 결과 확인
sales_2017.head(1)
# Out:
#    기준_년_코드  기준_분기_코드 상권_구분_코드 상권_구분_코드_명    상권_코드 상권_코드_명 서비스_업종_코드  \
# 0     2017         1        A       골목상권  2110001  이북5도청사  CS100001
#
#   서비스_업종_코드_명  분기당_매출_금액  분기당_매출_건수  주중_매출_비율  주말_매출_비율  월요일_매출_비율  화요일_매출_비율  \
# 0       한식음식점  816890247      28082        61        39         12         12
#
#    수요일_매출_비율  목요일_매출_비율  금요일_매출_비율  토요일_매출_비율  일요일_매출_비율  시간대_00~06_매출_비율  \
# 0         13         12         12         20         19                0
#
#    시간대_06~11_매출_비율  시간대_11~14_매출_비율  시간대_14~17_매출_비율  시간대_17~21_매출_비율  \
# 0                6               34               20               33
#
#    시간대_21~24_매출_비율  남성_매출_비율  여성_매출_비율  연령대_10_매출_비율  연령대_20_매출_비율  \
# 0                7        69        31             0             4
#
#    연령대_30_매출_비율  연령대_40_매출_비율  연령대_50_매출_비율  연령대_60_이상_매출_비율   주중_매출_금액  \
# 0            11            23            33               29  497915307
#
#     주말_매출_금액  월요일_매출_금액  화요일_매출_금액  수요일_매출_금액  목요일_매출_금액  금요일_매출_금액  \
# ...

# %% [markdown]
# ### 점포_상권

# %%
# 점포 데이터_상권 로드
store_2022 = pd.read_csv('/content/drive/MyDrive/MC_KDT/프로젝트/파이널프로젝트/데이터/서울시 상권분석서비스(상권-점포)_2022년.csv', encoding='cp949')
store_2021 = pd.read_csv('/content/drive/MyDrive/MC_KDT/프로젝트/파이널프로젝트/데이터/서울시_우리마을가게_상권분석서비스(신_상권_점포)_2021년.csv', encoding='cp949')
store_2020 = pd.read_csv('/content/drive/MyDrive/MC_KDT/프로젝트/파이널프로젝트/데이터/서울시_우리마을가게_상권분석서비스(신_상권_점포)_2020년.csv', encoding='cp949')
store_2019 = pd.read_csv('/content/drive/MyDrive/MC_KDT/프로젝트/파이널프로젝트/데이터/서울시_우리마을가게_상권분석서비스(신_상권_점포)_2019년.csv', encoding='cp949')
store_2018 = pd.read_csv('/content/drive/MyDrive/MC_KDT/프로젝트/파이널프로젝트/데이터/서울시_우리마을가게_상권분석서비스(신_상권_점포)_2018년.csv', encoding='cp949')
store_2017 = pd.read_csv('/content/drive/MyDrive/MC_KDT/프로젝트/파이널프로젝트/데이터/서울시_우리마을가게_상권분석서비스(신_상권_점포)_2017년.csv', encoding='cp949')

# %%
# 점포 데이터_상권 로드 결과 확인
store_2022.head(2)
# Out:
#    기준_년_코드  기준_분기_코드 상권_구분_코드 상권_구분_코드_명    상권_코드      상권_코드_명 서비스_업종_코드  \
# 0     2022         4        U       관광특구  1001496  강남 마이스 관광특구  CS300043
# 1     2022         4        U       관광특구  1001496  강남 마이스 관광특구  CS300042
#
#   서비스_업종_코드_명  점포_수  유사_업종_점포_수  개업_율  개업_점포_수  폐업_률  폐업_점포_수  프랜차이즈_점포_수
# 0      전자상거래업     6           6     0        0     0        0           0
# 1         주유소     1           1     0        0     0        0           0

# %% [markdown]
# ### 점포_상권배후지

# %%
# 점포 데이터_상권배후지 로드
hinterland_2022 = pd.read_csv('/content/drive/MyDrive/MC_KDT/프로젝트/파이널프로젝트/데이터/서울시 상권분석서비스(상권배후지-점포)_2022년.csv', encoding='cp949')
hinterland_2021 = pd.read_csv('/content/drive/MyDrive/MC_KDT/프로젝트/파이널프로젝트/데이터/서울시_우리마을가게_상권분석서비스(신_상권배후지_점포)_2021년.csv', encoding='cp949')
hinterland_2020 = pd.read_csv('/content/drive/MyDrive/MC_KDT/프로젝트/파이널프로젝트/데이터/서울시_우리마을가게_상권분석서비스(신_상권배후지_점포)_2020년.csv', encoding='cp949')
hinterland_2019 = pd.read_csv('/content/drive/MyDrive/MC_KDT/프로젝트/파이널프로젝트/데이터/서울시_우리마을가게_상권분석서비스(신_상권배후지_점포)_2019년.csv', encoding='cp949')
hinterland_2018 = pd.read_csv('/content/drive/MyDrive/MC_KDT/프로젝트/파이널프로젝트/데이터/서울시_우리마을가게_상권분석서비스(신_상권배후지_점포)_2018년.csv', encoding='cp949')
hinterland_2017 = pd.read_csv('/content/drive/MyDrive/MC_KDT/프로젝트/파이널프로젝트/데이터/서울시_우리마을가게_상권분석서비스(신_상권배후지_점포)_2017년.csv', encoding='cp949')

hinterland_2017.head(2)
# Out:
#    기준_년_코드  기준_분기_코드 상권_구분_코드 상권_구분_코드_명    상권_코드 상권_코드_명 서비스_업종_코드  \
# 0     2017         1        A       골목상권  2110001  이북5도청사  CS100001
# 1     2017         1        A       골목상권  2110001  이북5도청사  CS100002
#
#   서비스_업종_코드_명  점포_수  유사_업종_점포_수  개업_율  개업_점포_수  폐업_률  폐업_점포_수  프랜차이즈_점포_수
# 0       한식음식점    27          29     3        1     3        1           2
# 1       중식음식점     0           1     0        0     0        0           1

# %%
# 데이터 확인용 --> ex. '상권_코드'가 2110001 경우 뭐가 나오나
check_test = hinterland_2017[hinterland_2017['상권_코드'] == 2110001]

check_test
# Out:
#         기준_년_코드  기준_분기_코드 상권_구분_코드 상권_구분_코드_명    상권_코드 상권_코드_명 서비스_업종_코드  \
# 0          2017         1        A       골목상권  2110001  이북5도청사  CS100001
# 1          2017         1        A       골목상권  2110001  이북5도청사  CS100002
# 2          2017         1        A       골목상권  2110001  이북5도청사  CS100003
# 3          2017         1        A       골목상권  2110001  이북5도청사  CS100004
# 4          2017         1        A       골목상권  2110001  이북5도청사  CS100005
# ...         ...       ...      ...        ...      ...     ...       ...
# 259350     2017         4        A       골목상권  2110001  이북5도청사  CS300031
# 259351     2017         4        A       골목상권  2110001  이북5도청사  CS300035
# 259352     2017         4        A       골목상권  2110001  이북5도청사  CS300036
# 259353     2017         4        A       골목상권  2110001  이북5도청사  CS300041
# 259354     2017         4        A       골목상권  2110001  이북5도청사  CS300043
#
#        서비스_업종_코드_명  점포_수  유사_업종_점포_수  개업_율  개업_점포_수  폐업_률  폐업_점포_수  프랜차이즈_점포_수
# ...

# %%
# 점포 데이터_상권배후지 로드 결과 확인

# %% [markdown]
# ## 6년치 합치기

# %% [markdown]
# ### 점포데이터_상권

# %%
# 점포 데이터 컬럼 확인 ==> 모두 연도 데이터셋의 컬럼 일치 확인
print("■■■■2022 점포 컬럼\n", store_2022.columns)
print("■■■■2021 점포 컬럼\n", store_2021.columns)
print("■■■■2020 점포 컬럼\n", store_2020.columns)
print("■■■■2019 점포 컬럼\n", store_2019.columns)
print("■■■■2018 점포 컬럼\n", store_2018.columns)
print("■■■■2017 점포 컬럼\n", store_2017.columns)
# Out:
# ■■■■2022 점포 컬럼
#  Index(['기준_년_코드', '기준_분기_코드', '상권_구분_코드', '상권_구분_코드_명', '상권_코드', '상권_코드_명',
#        '서비스_업종_코드', '서비스_업종_코드_명', '점포_수', '유사_업종_점포_수', '개업_율', '개업_점포_수',
#        '폐업_률', '폐업_점포_수', '프랜차이즈_점포_수'],
#       dtype='object')
# ■■■■2021 점포 컬럼
#  Index(['기준_년_코드', '기준_분기_코드', '상권_구분_코드', '상권_구분_코드_명', '상권_코드', '상권_코드_명',
#        '서비스_업종_코드', '서비스_업종_코드_명', '점포_수', '유사_업종_점포_수', '개업_율', '개업_점포_수',
#        '폐업_률', '폐업_점포_수', '프랜차이즈_점포_수'],
#       dtype='object')
# ■■■■2020 점포 컬럼
#  Index(['기준_년_코드', '기준_분기_코드', '상권_구분_코드', '상권_구분_코드_명', '상권_코드', '상권_코드_명',
#        '서비스_업종_코드', '서비스_업종_코드_명', '점포_수', '유사_업종_점포_수', '개업_율', '개업_점포_수',
#        '폐업_률', '폐업_점포_수', '프랜차이즈_점포_수'],
#       dtype='object')
# ■■■■2019 점포 컬럼
#  Index(['기준_년_코드', '기준_분기_코드', '상권_구분_코드', '상권_구분_코드_명', '상권_코드', '상권_코드_명',
#        '서비스_업종_코드', '서비스_업종_코드_명', '점포_수', '유사_업종_점포_수', '개업_율', '개업_점포_수',
#        '폐업_률', '폐업_점포_수', '프랜차이즈_점포_수'],
#       dtype='object')
# ■■■■2018 점포 컬럼
# ...

# %%
### 점포 데이터 6개년 합치기
dfs = [store_2022, store_2021, store_2020, store_2019, store_2018, store_2017]
store_6years = pd.concat(dfs, ignore_index=True)
store_6years
# Out:
#          기준_년_코드  기준_분기_코드 상권_구분_코드 상권_구분_코드_명    상권_코드      상권_코드_명  \
# 0           2022         4        U       관광특구  1001496  강남 마이스 관광특구
# 1           2022         4        U       관광특구  1001496  강남 마이스 관광특구
# 2           2022         4        U       관광특구  1001496  강남 마이스 관광특구
# 3           2022         4        U       관광특구  1001496  강남 마이스 관광특구
# 4           2022         4        U       관광특구  1001496  강남 마이스 관광특구
# ...          ...       ...      ...        ...      ...          ...
# 1787962     2017         4        U       관광특구  1001496  강남 마이스 관광특구
# 1787963     2017         4        U       관광특구  1001496  강남 마이스 관광특구
# 1787964     2017         4        U       관광특구  1001496  강남 마이스 관광특구
# 1787965     2017         4        U       관광특구  1001496  강남 마이스 관광특구
# 1787966     2017         4        U       관광특구  1001496  강남 마이스 관광특구
#
#         서비스_업종_코드 서비스_업종_코드_명  점포_수  유사_업종_점포_수  개업_율  개업_점포_수  폐업_률  폐업_점포_수  \
# ...

# %% [markdown]
# ### 점포데이터_상권배후지

# %%
# 점포_배후지 데이터 컬럼 확인 ==> 모든 연도가 동일 컬럼임을 확인함
print("▶▶▶▶2022 점포_배후지 컬럼\n", hinterland_2022.columns)
print("▶▶▶▶2021 점포_배후지 컬럼\n", hinterland_2021.columns)
print("▶▶▶▶2020 점포_배후지 컬럼\n", hinterland_2020.columns)
print("▶▶▶▶2019 점포_배후지 컬럼\n", hinterland_2019.columns)
print("▶▶▶▶2018 점포_배후지 컬럼\n", hinterland_2018.columns)
print("▶▶▶▶2017 점포_배후지 컬럼\n", hinterland_2017.columns)
# Out:
# ▶▶▶▶2022 점포_배후지 컬럼
#  Index(['기준_년_코드', '기준_분기_코드', '상권_구분_코드', '상권_구분_코드_명', '상권_코드', '상권_코드_명',
#        '서비스_업종_코드', '서비스_업종_코드_명', '점포_수', '유사_업종_점포_수', '개업_율', '개업_점포_수',
#        '폐업_률', '폐업_점포_수', '프랜차이즈_점포_수'],
#       dtype='object')
# ▶▶▶▶2021 점포_배후지 컬럼
#  Index(['기준_년_코드', '기준_분기_코드', '상권_구분_코드', '상권_구분_코드_명', '상권_코드', '상권_코드_명',
#        '서비스_업종_코드', '서비스_업종_코드_명', '점포_수', '유사_업종_점포_수', '개업_율', '개업_점포_수',
#        '폐업_률', '폐업_점포_수', '프랜차이즈_점포_수'],
#       dtype='object')
# ▶▶▶▶2020 점포_배후지 컬럼
#  Index(['기준_년_코드', '기준_분기_코드', '상권_구분_코드', '상권_구분_코드_명', '상권_코드', '상권_코드_명',
#        '서비스_업종_코드', '서비스_업종_코드_명', '점포_수', '유사_업종_점포_수', '개업_율', '개업_점포_수',
#        '폐업_률', '폐업_점포_수', '프랜차이즈_점포_수'],
#       dtype='object')
# ▶▶▶▶2019 점포_배후지 컬럼
#  Index(['기준_년_코드', '기준_분기_코드', '상권_구분_코드', '상권_구분_코드_명', '상권_코드', '상권_코드_명',
#        '서비스_업종_코드', '서비스_업종_코드_명', '점포_수', '유사_업종_점포_수', '개업_율', '개업_점포_수',
#        '폐업_률', '폐업_점포_수', '프랜차이즈_점포_수'],
#       dtype='object')
# ...

# %%
### 6개년 합치기

dfs = [hinterland_2022, hinterland_2021, hinterland_2020, hinterland_2019, hinterland_2018, hinterland_2017]

hinterland_6years = pd.concat(dfs, ignore_index=True)
hinterland_6years = hinterland_6years.sort_values(by=['기준_년_코드', '기준_분기_코드'], ascending=[False, True])
hinterland_6years.reset_index(drop=True, inplace=True)
hinterland_6years
# Out:
#          기준_년_코드  기준_분기_코드 상권_구분_코드 상권_구분_코드_명    상권_코드  상권_코드_명 서비스_업종_코드  \
# 0           2022         1        A       골목상권  2111090  강일동주민센터  CS300043
# 1           2022         1        A       골목상권  2111090  강일동주민센터  CS300038
# 2           2022         1        A       골목상권  2111090  강일동주민센터  CS300036
# 3           2022         1        A       골목상권  2111090  강일동주민센터  CS300035
# 4           2022         1        A       골목상권  2111090  강일동주민센터  CS300034
# ...          ...       ...      ...        ...      ...      ...       ...
# 2073897     2017         4        A       골목상권  2111090  강일동주민센터  CS300029
# 2073898     2017         4        A       골목상권  2111090  강일동주민센터  CS300032
# 2073899     2017         4        A       골목상권  2111090  강일동주민센터  CS300036
# 2073900     2017         4        A       골목상권  2111090  강일동주민센터  CS300038
# 2073901     2017         4        A       골목상권  2111090  강일동주민센터  CS300043
#
# ...

# %%
hinterland_6years = hinterland_6years.rename(columns = {'유사_업종_점포_수':'배후지_총점포수', '점포_수':'배후지_점포수', '개업_점포_수':'배후지_개업점포수', '폐업_점포_수':'배후지_폐업점포수',
                                                        '프랜차이즈_점포_수':'배후지_프랜차이즈점포수'})
hinterland_6years.head(2)
# Out:
#    기준_년_코드  기준_분기_코드 상권_구분_코드 상권_구분_코드_명    상권_코드  상권_코드_명 서비스_업종_코드  \
# 0     2022         1        A       골목상권  2111090  강일동주민센터  CS300043
# 1     2022         1        A       골목상권  2111090  강일동주민센터  CS300038
#
#   서비스_업종_코드_명  배후지_점포수  배후지_총점포수  개업_율  배후지_개업점포수  폐업_률  배후지_폐업점포수  \
# 0      전자상거래업        6         6     0          0     0          0
# 1       자동차부품        2         2     0          0     0          0
#
#    배후지_프랜차이즈점포수
# 0             0
# 1             0

# %%
hinterland_6years.columns
# Out:
# Index(['기준_년_코드', '기준_분기_코드', '상권_구분_코드', '상권_구분_코드_명', '상권_코드', '상권_코드_명',
#        '서비스_업종_코드', '서비스_업종_코드_명', '배후지_점포수', '배후지_총점포수', '개업_율', '배후지_개업점포수',
#        '폐업_률', '배후지_폐업점포수', '배후지_프랜차이즈점포수'],
#       dtype='object')

# %%
# '상권_코드' 열의 값이 2110804 '서비스_업종_코드' 열의 값이 'CS200003'인 행 추출
target_row = hinterland_6years[(hinterland_6years['상권_코드'] == 2110804) & (hinterland_6years['서비스_업종_코드'] == 'CS200003')]
target_row
# Out:
#          기준_년_코드  기준_분기_코드 상권_구분_코드 상권_구분_코드_명    상권_코드 상권_코드_명 서비스_업종_코드  \
# 22946       2022         1        A       골목상권  2110804  신풍역 1번  CS200003
# 109262      2022         2        A       골목상권  2110804  신풍역 1번  CS200003
# 195576      2022         3        A       골목상권  2110804  신풍역 1번  CS200003
# 281912      2022         4        A       골목상권  2110804  신풍역 1번  CS200003
# 408722      2021         1        A       골목상권  2110804  신풍역 1번  CS200003
# 495127      2021         2        A       골목상권  2110804  신풍역 1번  CS200003
# 581500      2021         3        A       골목상권  2110804  신풍역 1번  CS200003
# 667873      2021         4        A       골목상권  2110804  신풍역 1번  CS200003
# 754445      2020         1        A       골목상권  2110804  신풍역 1번  CS200003
# 841017      2020         2        A       골목상권  2110804  신풍역 1번  CS200003
# 927535      2020         3        A       골목상권  2110804  신풍역 1번  CS200003
# 1014019     2020         4        A       골목상권  2110804  신풍역 1번  CS200003
# ...

# %% [markdown]
# ### 매출데이터

# %%
# 매출 데이터 컬럼 확인 ==> 모든 연도가 동일 컬럼임을 확인함
print("▶▶▶▶2022 매출 컬럼\n", sales_2022.columns)
print("▶▶▶▶2021 매출 컬럼\n", sales_2021.columns)
print("▶▶▶▶2020 매출 컬럼\n", sales_2020.columns)
print("▶▶▶▶2019 매출 컬럼\n", sales_2019.columns)
print("▶▶▶▶2018 매출 컬럼\n", sales_2018.columns)
print("▶▶▶▶2017 매출 컬럼\n", sales_2017.columns)
# Out:
# ▶▶▶▶2022 매출 컬럼
#  Index(['기준_년_코드', '기준_분기_코드', '상권_구분_코드', '상권_구분_코드_명', '상권_코드', '상권_코드_명',
#        '서비스_업종_코드', '서비스_업종_코드_명', '분기당_매출_금액', '분기당_매출_건수', '주중_매출_비율',
#        '주말_매출_비율', '월요일_매출_비율', '화요일_매출_비율', '수요일_매출_비율', '목요일_매출_비율',
#        '금요일_매출_비율', '토요일_매출_비율', '일요일_매출_비율', '시간대_00~06_매출_비율',
#        '시간대_06~11_매출_비율', '시간대_11~14_매출_비율', '시간대_14~17_매출_비율',
#        '시간대_17~21_매출_비율', '시간대_21~24_매출_비율', '남성_매출_비율', '여성_매출_비율',
#        '연령대_10_매출_비율', '연령대_20_매출_비율', '연령대_30_매출_비율', '연령대_40_매출_비율',
#        '연령대_50_매출_비율', '연령대_60_이상_매출_비율', '주중_매출_금액', '주말_매출_금액', '월요일_매출_금액',
#        '화요일_매출_금액', '수요일_매출_금액', '목요일_매출_금액', '금요일_매출_금액', '토요일_매출_금액',
#        '일요일_매출_금액', '시간대_00~06_매출_금액', '시간대_06~11_매출_금액', '시간대_11~14_매출_금액',
#        '시간대_14~17_매출_금액', '시간대_17~21_매출_금액', '시간대_21~24_매출_금액', '남성_매출_금액',
#        '여성_매출_금액', '연령대_10_매출_금액', '연령대_20_매출_금액', '연령대_30_매출_금액',
#        '연령대_40_매출_금액', '연령대_50_매출_금액', '연령대_60_이상_매출_금액', '주중_매출_건수',
# ...

# %%
### 매출 데이터 6개년 합치기 --> 열은 모두 똑같길래 concat 사용
dfs = [sales_2022, sales_2021, sales_2020, sales_2019, sales_2018, sales_2017]
sales_6years = pd.concat(dfs, ignore_index=True)
sales_6years
# Out:
#         기준_년_코드  기준_분기_코드 상권_구분_코드 상권_구분_코드_명    상권_코드      상권_코드_명 서비스_업종_코드  \
# 0          2022         4        D       발달상권  2120139      대림3동사거리  CS300031
# 1          2022         4        D       발달상권  2120068         사가정역  CS100005
# 2          2022         4        R       전통시장  2130322     고분다리전통시장  CS300018
# 3          2022         4        D       발달상권  2120230   송파사거리(송파역)  CS300017
# 4          2022         4        D       발달상권  2120234        가락시장역  CS200016
# ...         ...       ...      ...        ...      ...          ...       ...
# 928233     2017         4        U       관광특구  1001496  강남 마이스 관광특구  CS300031
# 928234     2017         4        U       관광특구  1001496  강남 마이스 관광특구  CS300032
# 928235     2017         4        U       관광특구  1001496  강남 마이스 관광특구  CS300035
# 928236     2017         4        U       관광특구  1001496  강남 마이스 관광특구  CS300041
# 928237     2017         4        U       관광특구  1001496  강남 마이스 관광특구  CS300043
#
# ...

# %%
# 데이터 확인용 --> ex. '상권_코드'가 1001496일 경우 뭐가 나오나
check_test = sales_6years[sales_6years['상권_코드'] == 1001496]

check_test.head(30)
# Out:
#        기준_년_코드  기준_분기_코드 상권_구분_코드 상권_구분_코드_명    상권_코드      상권_코드_명 서비스_업종_코드  \
# 3308      2022         4        U       관광특구  1001496  강남 마이스 관광특구  CS200028
# 3310      2022         4        U       관광특구  1001496  강남 마이스 관광특구  CS100003
# 3979      2022         4        U       관광특구  1001496  강남 마이스 관광특구  CS300022
# 3981      2022         4        U       관광특구  1001496  강남 마이스 관광특구  CS300018
# 3983      2022         4        U       관광특구  1001496  강남 마이스 관광특구  CS300002
# 12092     2022         4        U       관광특구  1001496  강남 마이스 관광특구  CS300043
# 12094     2022         4        U       관광특구  1001496  강남 마이스 관광특구  CS300031
# 12096     2022         4        U       관광특구  1001496  강남 마이스 관광특구  CS300021
# 20364     2022         4        U       관광특구  1001496  강남 마이스 관광특구  CS200024
# 20366     2022         4        U       관광특구  1001496  강남 마이스 관광특구  CS100010
# 20368     2022         4        U       관광특구  1001496  강남 마이스 관광특구  CS100008
# ...

# %%
### 상권코드에 맞춰 자치구, 행정동 끌어오기

# '자치구', '행정동' 열 생성
sales_6years['자치구'] = ''
sales_6years['행정동'] = ''

# 자치구, 행정동 채우기
for index, row in sales_6years.iterrows():
    mask = seoul_gudong['상권_코드'] == row['상권_코드']
    matching_data = seoul_gudong[mask]
    if not matching_data.empty:
        sales_6years.at[index, '자치구'] = matching_data['자치구'].values[0]
        sales_6years.at[index, '행정동'] = matching_data['행정동'].values[0]

sales_6years
# Out:
#         기준_년_코드  기준_분기_코드 상권_구분_코드 상권_구분_코드_명    상권_코드      상권_코드_명 서비스_업종_코드  \
# 0          2022         4        D       발달상권  2120139      대림3동사거리  CS300031
# 1          2022         4        D       발달상권  2120068         사가정역  CS100005
# 2          2022         4        R       전통시장  2130322     고분다리전통시장  CS300018
# 3          2022         4        D       발달상권  2120230   송파사거리(송파역)  CS300017
# 4          2022         4        D       발달상권  2120234        가락시장역  CS200016
# ...         ...       ...      ...        ...      ...          ...       ...
# 928233     2017         4        U       관광특구  1001496  강남 마이스 관광특구  CS300031
# 928234     2017         4        U       관광특구  1001496  강남 마이스 관광특구  CS300032
# 928235     2017         4        U       관광특구  1001496  강남 마이스 관광특구  CS300035
# 928236     2017         4        U       관광특구  1001496  강남 마이스 관광특구  CS300041
# 928237     2017         4        U       관광특구  1001496  강남 마이스 관광특구  CS300043
#
# ...

# %% [markdown]
# ### 매출+점포 병합

# %%
# 두 데이터프레임 (sales, store)의 지정 컬럼의 값이 같을 때 점포데이터의 남은 컬럼 값 가져오기
df_merged = pd.merge(sales_6years, store_6years, on=['기준_년_코드', '기준_분기_코드', '상권_구분_코드', '상권_구분_코드_명', '상권_코드', '상권_코드_명', '서비스_업종_코드', '서비스_업종_코드_명'], how='inner')

# %%
# 총 매출 금액 컬럼 생성
df_merged['총_매출_금액'] = df_merged['주중_매출_금액'] + df_merged['주말_매출_금액']
df_merged.columns
# Out:
# Index(['기준_년_코드', '기준_분기_코드', '상권_구분_코드', '상권_구분_코드_명', '상권_코드', '상권_코드_명',
#        '서비스_업종_코드', '서비스_업종_코드_명', '분기당_매출_금액', '분기당_매출_건수', '주중_매출_비율',
#        '주말_매출_비율', '월요일_매출_비율', '화요일_매출_비율', '수요일_매출_비율', '목요일_매출_비율',
#        '금요일_매출_비율', '토요일_매출_비율', '일요일_매출_비율', '시간대_00~06_매출_비율',
#        '시간대_06~11_매출_비율', '시간대_11~14_매출_비율', '시간대_14~17_매출_비율',
#        '시간대_17~21_매출_비율', '시간대_21~24_매출_비율', '남성_매출_비율', '여성_매출_비율',
#        '연령대_10_매출_비율', '연령대_20_매출_비율', '연령대_30_매출_비율', '연령대_40_매출_비율',
#        '연령대_50_매출_비율', '연령대_60_이상_매출_비율', '주중_매출_금액', '주말_매출_금액', '월요일_매출_금액',
#        '화요일_매출_금액', '수요일_매출_금액', '목요일_매출_금액', '금요일_매출_금액', '토요일_매출_금액',
#        '일요일_매출_금액', '시간대_00~06_매출_금액', '시간대_06~11_매출_금액', '시간대_11~14_매출_금액',
#        '시간대_14~17_매출_금액', '시간대_17~21_매출_금액', '시간대_21~24_매출_금액', '남성_매출_금액',
#        '여성_매출_금액', '연령대_10_매출_금액', '연령대_20_매출_금액', '연령대_30_매출_금액',
#        '연령대_40_매출_금액', '연령대_50_매출_금액', '연령대_60_이상_매출_금액', '주중_매출_건수',
# ...

# %%
# 필요한 컬럼만 추출
df_preprocessed = df_merged[['기준_년_코드', '기준_분기_코드', '자치구', '행정동', '상권_코드', '서비스_업종_코드', '서비스_업종_코드_명', '점포_수', '유사_업종_점포_수',
                             '개업_율', '개업_점포_수', '폐업_률', '폐업_점포_수', '프랜차이즈_점포_수',
                             '총_매출_금액', '분기당_매출_금액', '주중_매출_금액', '주말_매출_금액', '남성_매출_금액', '여성_매출_금액']]
df_preprocessed
# Out:
#         기준_년_코드  기준_분기_코드   자치구     행정동    상권_코드 서비스_업종_코드 서비스_업종_코드_명  점포_수  \
# 0          2022         4  영등포구    대림3동  2120139  CS300031          가구     2
# 1          2022         4   중랑구  면목3.8동  2120068  CS100005         제과점     3
# 2          2022         4   강동구    천호3동  2130322  CS300018         의약품     3
# 3          2022         4   송파구     석촌동  2120230  CS300017      시계및귀금속     4
# 4          2022         4   송파구    가락본동  2120234  CS200016         당구장    11
# ...         ...       ...   ...     ...      ...       ...         ...   ...
# 912344     2017         4   강남구    삼성1동  1001496  CS300031          가구     9
# 912345     2017         4   강남구    삼성1동  1001496  CS300032        가전제품     9
# 912346     2017         4   강남구    삼성1동  1001496  CS300035        인테리어     4
# 912347     2017         4   강남구    삼성1동  1001496  CS300041         예술품     9
# 912348     2017         4   강남구    삼성1동  1001496  CS300043      전자상거래업     8
#
# ...

# %%
df_preprocessed.자치구.nunique()
# Out:
# 25

# %% [markdown]
# ### 대분류, 중분류 붙이기

# %%
### '서비스_업종_코드_명'(업종명)에 따라 대분류, 중분류 채우기

# '대분류', '중분류' 컬럼 생성
df_preprocessed['대분류'] = ''
df_preprocessed['중분류'] = ''

# 중분류, 대분류 채우기
for index, row in df_preprocessed.iterrows():
    mask = category['업종명'] == row['서비스_업종_코드_명']
    matching_data = category[mask]
    if not matching_data.empty:
        df_preprocessed.at[index, '대분류'] = matching_data['대분류'].values[0]
        df_preprocessed.at[index, '중분류'] = matching_data['중분류'].values[0]

# 결과 확인
df_preprocessed
# Out:
# <ipython-input-15-20e146ff1257>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_preprocessed['대분류'] = ''
# <ipython-input-15-20e146ff1257>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_preprocessed['중분류'] = ''
#         기준_년_코드  기준_분기_코드   자치구     행정동    상권_코드 서비스_업종_코드 서비스_업종_코드_명  점포_수  \
# 0          2022         4  영등포구    대림3동  2120139  CS300031          가구     2
# 1          2022         4   중랑구  면목3.8동  2120068  CS100005         제과점     3
# ...

# %%
df_preprocessed.columns
# Out:
# Index(['기준_년_코드', '기준_분기_코드', '자치구', '행정동', '상권_코드', '서비스_업종_코드',
#        '서비스_업종_코드_명', '점포_수', '유사_업종_점포_수', '개업_율', '개업_점포_수', '폐업_률',
#        '폐업_점포_수', '프랜차이즈_점포_수', '총_매출_금액', '분기당_매출_금액', '주중_매출_금액', '주말_매출_금액',
#        '남성_매출_금액', '여성_매출_금액', '대분류', '중분류'],
#       dtype='object')

# %%
# 필요한 컬럼만 추출
df_preprocessed = df_preprocessed[['기준_년_코드', '기준_분기_코드', '자치구', '행정동', '대분류', '중분류', '상권_코드', '서비스_업종_코드', '서비스_업종_코드_명', '점포_수', '유사_업종_점포_수',
                             '개업_율', '개업_점포_수', '폐업_률', '폐업_점포_수', '프랜차이즈_점포_수',
                             '총_매출_금액', '분기당_매출_금액', '주중_매출_금액', '주말_매출_금액', '남성_매출_금액', '여성_매출_금액']]
df_preprocessed.head()
# Out:
#    기준_년_코드  기준_분기_코드   자치구     행정동  대분류      중분류    상권_코드 서비스_업종_코드  \
# 0     2022         4  영등포구    대림3동   소매  가구/인테리어  2120139  CS300031
# 1     2022         4   중랑구  면목3.8동   외식  카페/베이커리  2120068  CS100005
# 2     2022         4   강동구    천호3동   소매       의료  2130322  CS300018
# 3     2022         4   송파구     석촌동   소매    의류/잡화  2120230  CS300017
# 4     2022         4   송파구    가락본동  서비스       오락  2120234  CS200016
#
#   서비스_업종_코드_명  점포_수  유사_업종_점포_수  개업_율  개업_점포_수  폐업_률  폐업_점포_수  프랜차이즈_점포_수  \
# 0          가구     2           2     0        0     0        0           0
# 1         제과점     3           5    20        1     0        0           2
# 2         의약품     3           3     0        0     0        0           0
# 3      시계및귀금속     4           5     0        0     0        0           1
# 4         당구장    11          12     0        0     0        0           1
#
#       총_매출_금액   분기당_매출_금액   주중_매출_금액   주말_매출_금액   남성_매출_금액   여성_매출_금액
# ...

# %%
# 총 점포수 컬럼 추가
df_preprocessed['순점포증감률'] = (df_preprocessed['개업_점포_수'] - df_preprocessed['폐업_점포_수']) / df_preprocessed['유사_업종_점포_수']

# 컬럼 명 변경
df_preprocessed.rename(columns={'유사_업종_점포_수': '총_점포수'}, inplace=True)


df_preprocessed.head(1)
# Out:
# <ipython-input-18-6b4d00b9bbf8>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_preprocessed['순점포증감률'] = (df_preprocessed['개업_점포_수'] - df_preprocessed['폐업_점포_수']) / df_preprocessed['유사_업종_점포_수']
# <ipython-input-18-6b4d00b9bbf8>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_preprocessed.rename(columns={'유사_업종_점포_수': '총_점포수'}, inplace=True)
#    기준_년_코드  기준_분기_코드   자치구   행정동 대분류      중분류    상권_코드 서비스_업종_코드 서비스_업종_코드_명  \
# 0     2022         4  영등포구  대림3동  소매  가구/인테리어  2120139  CS300031          가구
#
# ...

# %%
df_preprocessed.columns
# Out:
# Index(['기준_년_코드', '기준_분기_코드', '자치구', '행정동', '대분류', '중분류', '상권_코드', '서비스_업종_코드',
#        '서비스_업종_코드_명', '점포_수', '총_점포수', '개업_율', '개업_점포_수', '폐업_률', '폐업_점포_수',
#        '프랜차이즈_점포_수', '총_매출_금액', '분기당_매출_금액', '주중_매출_금액', '주말_매출_금액',
#        '남성_매출_금액', '여성_매출_금액', '순점포증감률'],
#       dtype='object')

# %%
df_preprocessed = df_preprocessed[['기준_년_코드', '기준_분기_코드', '자치구', '행정동', '대분류', '중분류', '상권_코드', '서비스_업종_코드', '서비스_업종_코드_명', '점포_수', '총_점포수', '순점포증감률', '개업_율', '개업_점포_수', '폐업_률', '폐업_점포_수',
                                   '프랜차이즈_점포_수', '총_매출_금액', '분기당_매출_금액', '주중_매출_금액', '주말_매출_금액', '남성_매출_금액', '여성_매출_금액']]
df_preprocessed.head(2)
# Out:
#    기준_년_코드  기준_분기_코드   자치구     행정동 대분류      중분류    상권_코드 서비스_업종_코드  \
# 0     2022         4  영등포구    대림3동  소매  가구/인테리어  2120139  CS300031
# 1     2022         4   중랑구  면목3.8동  외식  카페/베이커리  2120068  CS100005
#
#   서비스_업종_코드_명  점포_수  총_점포수  순점포증감률  개업_율  개업_점포_수  폐업_률  폐업_점포_수  프랜차이즈_점포_수  \
# 0          가구     2      2     0.0     0        0     0        0           0
# 1         제과점     3      5     0.2    20        1     0        0           2
#
#       총_매출_금액   분기당_매출_금액   주중_매출_금액   주말_매출_금액   남성_매출_금액   여성_매출_금액
# 0   205619535   205619535  205619535          0   12549549  193069986
# 1  1111094837  1111094837  759670537  351424300  405775472  623495718

# %%
df_preprocessed.isnull().sum()
# Out:
# 기준_년_코드        0
# 기준_분기_코드       0
# 자치구            0
# 행정동            0
# 대분류            0
# 중분류            0
# 상권_코드          0
# 서비스_업종_코드      0
# 서비스_업종_코드_명    0
# 점포_수           0
# 총_점포수          0
# 순점포증감률         3
# 개업_율           0
# 개업_점포_수        0
# 폐업_률           0
# 폐업_점포_수        0
# 프랜차이즈_점포_수     0
# 총_매출_금액        0
# 분기당_매출_금액      0
# 주중_매출_금액       0
# 주말_매출_금액       0
# 남성_매출_금액       0
# 여성_매출_금액       0
# dtype: int64

# %%
df_preprocessed[df_preprocessed['순점포증감률'].isna()]
# Out:
#         기준_년_코드  기준_분기_코드  자치구     행정동  대분류  중분류    상권_코드 서비스_업종_코드  \
# 213155     2021         3  도봉구    방학3동   외식  식사류  2110386  CS100008
# 214382     2021         3  노원구  상계3.4동   외식  식사류  2110437  CS100002
# 666023     2018         3  강서구    방화2동  서비스   미용  2110633  CS200030
#
#        서비스_업종_코드_명  점포_수  총_점포수  순점포증감률  개업_율  개업_점포_수  폐업_률  폐업_점포_수  \
# 213155       분식전문점     0      0     NaN     0        1     0        1
# 214382       중식음식점     0      0     NaN     0        1     0        1
# 666023       피부관리실     0      0     NaN     0        1     0        1
#
#         프랜차이즈_점포_수   총_매출_금액  분기당_매출_금액  주중_매출_금액  주말_매출_금액  남성_매출_금액  \
# 213155           0   6396092    6396092   5568161    827931   2048682
# 214382           0  15000000   15000000   7861161   7138839   8840344
# 666023           0   4076642    4076642   3429991    646651   1535797
#
#         여성_매출_금액
# 213155   4210136
# 214382   6159656
# 666023   2540845

# %%
# '순점포증감률' 열의 NaN 값을 0으로 변경
df_preprocessed['순점포증감률'] = df_preprocessed['순점포증감률'].fillna(0)
df_preprocessed[df_preprocessed['순점포증감률'].isna()]
# Out:
# Empty DataFrame
# Columns: [기준_년_코드, 기준_분기_코드, 자치구, 행정동, 대분류, 중분류, 상권_코드, 서비스_업종_코드, 서비스_업종_코드_명, 점포_수, 총_점포수, 순점포증감률, 개업_율, 개업_점포_수, 폐업_률, 폐업_점포_수, 프랜차이즈_점포_수, 총_매출_금액, 분기당_매출_금액, 주중_매출_금액, 주말_매출_금액, 남성_매출_금액, 여성_매출_금액]
# Index: []

# %%
df_preprocessed.isnull().sum()
# Out:
# 기준_년_코드        0
# 기준_분기_코드       0
# 자치구            0
# 행정동            0
# 대분류            0
# 중분류            0
# 상권_코드          0
# 서비스_업종_코드      0
# 서비스_업종_코드_명    0
# 점포_수           0
# 총_점포수          0
# 순점포증감률         0
# 개업_율           0
# 개업_점포_수        0
# 폐업_률           0
# 폐업_점포_수        0
# 프랜차이즈_점포_수     0
# 총_매출_금액        0
# 분기당_매출_금액      0
# 주중_매출_금액       0
# 주말_매출_금액       0
# 남성_매출_금액       0
# 여성_매출_금액       0
# dtype: int64

# %%
df_preprocessed
# Out:
#         기준_년_코드  기준_분기_코드   자치구     행정동  대분류      중분류    상권_코드 서비스_업종_코드  \
# 0          2022         4  영등포구    대림3동   소매  가구/인테리어  2120139  CS300031
# 1          2022         4   중랑구  면목3.8동   외식  카페/베이커리  2120068  CS100005
# 2          2022         4   강동구    천호3동   소매       의료  2130322  CS300018
# 3          2022         4   송파구     석촌동   소매    의류/잡화  2120230  CS300017
# 4          2022         4   송파구    가락본동  서비스       오락  2120234  CS200016
# ...         ...       ...   ...     ...  ...      ...      ...       ...
# 912344     2017         4   강남구    삼성1동   소매  가구/인테리어  1001496  CS300031
# 912345     2017         4   강남구    삼성1동   소매  가구/인테리어  1001496  CS300032
# 912346     2017         4   강남구    삼성1동   소매  가구/인테리어  1001496  CS300035
# 912347     2017         4   강남구    삼성1동   소매  가구/인테리어  1001496  CS300041
# 912348     2017         4   강남구    삼성1동   소매       유통  1001496  CS300043
#
#        서비스_업종_코드_명  점포_수  총_점포수  순점포증감률  개업_율  개업_점포_수  폐업_률  폐업_점포_수  \
# ...

# %%
df_preprocessed = df_preprocessed.sort_values(by=['기준_년_코드', '기준_분기_코드'], ascending=[False, True])
df_preprocessed.reset_index(drop=True, inplace=True)

df_preprocessed
# Out:
#         기준_년_코드  기준_분기_코드   자치구    행정동  대분류      중분류    상권_코드 서비스_업종_코드  \
# 0          2022         1  서대문구  북가좌2동  서비스       의료  2110499  CS200008
# 1          2022         1   노원구   공릉1동   소매    의류/잡화  2110433  CS300016
# 2          2022         1   마포구   성산1동   소매     전자기기  2110548  CS300003
# 3          2022         1   은평구    대조동  서비스       미용  2110481  CS200030
# 4          2022         1  영등포구   신길6동  서비스       교육  2110804  CS200003
# ...         ...       ...   ...    ...  ...      ...      ...       ...
# 912344     2017         4   강남구   삼성1동   소매  가구/인테리어  1001496  CS300031
# 912345     2017         4   강남구   삼성1동   소매  가구/인테리어  1001496  CS300032
# 912346     2017         4   강남구   삼성1동   소매  가구/인테리어  1001496  CS300035
# 912347     2017         4   강남구   삼성1동   소매  가구/인테리어  1001496  CS300041
# 912348     2017         4   강남구   삼성1동   소매       유통  1001496  CS300043
#
#        서비스_업종_코드_명  점포_수  총_점포수    순점포증감률  개업_율  개업_점포_수  폐업_률  폐업_점포_수  \
# ...

# %%
# df_preprocessed.to_csv('/content/drive/MyDrive/MC_KDT/프로젝트/파이널프로젝트/데이터/0728_Seoul_상권만.csv', encoding='euc-kr')

# %% [markdown]
# ## 데이터 추가 : 생활인구

# %%
# 생활인구 데이터 로드
pop = pd.read_csv('/content/drive/MyDrive/MC_KDT/프로젝트/파이널프로젝트/데이터/서울시 상권분석서비스(상권-생활인구).csv', encoding='cp949')
pop
# Out:
#        기준 년코드  기준_분기_코드  상권_구분_코드_명    상권_코드                 상권_코드_명  \
# 0        2022         4        관광특구  1001496             강남 마이스 관광특구
# 1        2022         4        관광특구  1001495                 잠실 관광특구
# 2        2022         4        관광특구  1001494              종로?청계 관광특구
# 3        2022         4        관광특구  1001493            동대문패션타운 관광특구
# 4        2022         4        관광특구  1001492  명동 남대문 북창동 다동 무교동 관광특구
# ...       ...       ...         ...      ...                     ...
# 40036    2017         1        골목상권  2110005                     세검정
# 40037    2017         1        골목상권  2110004                  대신고등학교
# 40038    2017         1        골목상권  2110003                 세검정초등학교
# 40039    2017         1        골목상권  2110002                 독립문역 1번
# 40040    2017         1        골목상권  2110001                  이북5도청사
#
#        총_생활인구_수  남성_생활인구_수  여성_생활인구_수
# 0        112658      55901      56757
# 1       3632727    1757144    1875581
# ...

# %%
# '기준 년코드' 컬럼 이름을 '기준_년_코드'로 변경
pop.rename(columns={'기준 년코드': '기준_년_코드'}, inplace=True)
pop.head()
# Out:
#    기준_년_코드  기준_분기_코드  상권_구분_코드_명    상권_코드                 상권_코드_명  총_생활인구_수  \
# 0     2022         4        관광특구  1001496             강남 마이스 관광특구    112658
# 1     2022         4        관광특구  1001495                 잠실 관광특구   3632727
# 2     2022         4        관광특구  1001494              종로?청계 관광특구   3957665
# 3     2022         4        관광특구  1001493            동대문패션타운 관광특구   3249964
# 4     2022         4        관광특구  1001492  명동 남대문 북창동 다동 무교동 관광특구   4667755
#
#    남성_생활인구_수  여성_생활인구_수
# 0      55901      56757
# 1    1757144    1875581
# 2    2127522    1830142
# 3    1534697    1715268
# 4    2345370    2322385

# %%
# ### 상권코드로 합치면 업종별로 데이터가 중복되어 중단
# df_merged2 = pd.merge(df_preprocessed, pop[['기준_년_코드', '기준_분기_코드', '상권_코드', '총_생활인구_수', '남성_생활인구_수', '여성_생활인구_수']], on=['기준_년_코드', '기준_분기_코드', '상권_코드'], how='inner')

# # 결과 확인
# df_merged2

# %%
# # 데이터 확인용 --> ex. '상권_코드'가 1001496일 경우 뭐가 나오나
# df_merged2 = df_merged2[df_merged2['상권_코드'] == 1001496]

# df_merged2.head()

# %% [markdown]
# ## 데이터 추가 : 지출

# %%
expense = pd.read_csv('/content/drive/MyDrive/MC_KDT/프로젝트/파이널프로젝트/데이터/서울시 상권분석서비스(상권-소득소비).csv', encoding='cp949')
expense
# Out:
#        기준_년_코드  기준_분기_코드 상권_구분_코드 상권_구분_코드_명    상권_코드                 상권_코드_명  \
# 0         2022         4        A       골목상권  2110001                  이북5도청사
# 1         2022         4        A       골목상권  2110002                 독립문역 1번
# 2         2022         4        A       골목상권  2110003                 세검정초등학교
# 3         2022         4        A       골목상권  2110004                  대신고등학교
# 4         2022         4        A       골목상권  2110005                     세검정
# ...        ...       ...      ...        ...      ...                     ...
# 39077     2017         1        U       관광특구  1001492  명동 남대문 북창동 다동 무교동 관광특구
# 39078     2017         1        U       관광특구  1001493            동대문패션타운 관광특구
# 39079     2017         1        U       관광특구  1001494              종로?청계 관광특구
# 39080     2017         1        U       관광특구  1001495                 잠실 관광특구
# 39081     2017         1        U       관광특구  1001496             강남 마이스 관광특구
#
# ...

# %%
# ### '서비스_업종_코드_명'(업종명)에 따라 중분류 채우기

# # 중분류 컬럼 생성
# df_preprocessed['중분류'] = ''

# # 조건에 따라 '중분류' 열의 값을 채움
# for index, row in df_preprocessed.iterrows():
#     mask = mid_category['업종명'] == row['서비스_업종_코드_명']
#     matching_data = mid_category[mask]
#     if not matching_data.empty:
#         df_preprocessed.at[index, '중분류'] = matching_data['중분류'].values[0]

# df_preprocessed

# %%
# df_preprocessed.columns

# %% [markdown]
# ### 컬럼순서 및 이름 바꾸기

# %%
# ### 컬럼 순서 바꾸고 컬럼명 변경
# df_preprocessed = df_preprocessed[['기준_년_코드', '기준_분기_코드', '자치구', '행정동', '중분류',
#                                    '서비스_업종_코드_명', '점포_수', '유사_업종_점포_수', '개업_율', '개업_점포_수', '폐업_률', '폐업_점포_수', '프랜차이즈_점포_수',
#                                    '분기당_매출_금액', '분기당_매출_건수',
#                                    '주중_매출_금액', '주말_매출_금액', '월요일_매출_금액','화요일_매출_금액', '수요일_매출_금액', '목요일_매출_금액', '금요일_매출_금액', '토요일_매출_금액', '일요일_매출_금액',
#                                    '시간대_00~06_매출_금액', '시간대_06~11_매출_금액', '시간대_11~14_매출_금액', '시간대_14~17_매출_금액', '시간대_17~21_매출_금액', '시간대_21~24_매출_금액', '남성_매출_금액', '여성_매출_금액',
#                                    '주중_매출_건수', '주말_매출_건수', '월요일_매출_건수', '화요일_매출_건수', '수요일_매출_건수', '목요일_매출_건수', '금요일_매출_건수', '토요일_매출_건수', '일요일_매출_건수',
#                                    '시간대_건수~06_매출_건수','시간대_건수~11_매출_건수', '시간대_건수~14_매출_건수', '시간대_건수~17_매출_건수', '시간대_건수~21_매출_건수', '시간대_건수~24_매출_건수',
#                                    '남성_매출_건수', '여성_매출_건수',
#                                    '주중_매출_비율', '주말_매출_비율', '월요일_매출_비율', '화요일_매출_비율', '수요일_매출_비율', '목요일_매출_비율', '금요일_매출_비율', '토요일_매출_비율', '일요일_매출_비율',
#                                    '시간대_00~06_매출_비율', '시간대_06~11_매출_비율', '시간대_11~14_매출_비율', '시간대_14~17_매출_비율', '시간대_17~21_매출_비율', '시간대_21~24_매출_비율',
#                                    '남성_매출_비율', '여성_매출_비율']]

# # 컬럼명 변경
# df = df_preprocessed.rename(columns = {'기준_년_코드':'기준_년',
#                                        '기준_분기_코드':'기준_분기',
#                                        '서비스_업종_코드_명':'업종명',
#                                        '유사_업종_점포_수':'총_점포수',
#                                        '개업_율':'개업률',
#                                        '폐업_률':'폐업률',
#                                        '시간대_00~06_매출_금액':'00~06시_매출금액', '시간대_06~11_매출_금액':'06~11시_매출금액', '시간대_11~14_매출_금액':'11~14시_매출금액',
#                                        '시간대_14~17_매출_금액':'14~17시_매출금액', '시간대_17~21_매출_금액':'17~21시_매출금액', '시간대_21~24_매출_금액':'21~24시_매출금액'})

# df.head()

# %% [markdown]
# # 전처리 파일 확인

# %%
df = pd.read_csv('/content/drive/MyDrive/MC_KDT/프로젝트/파이널프로젝트/데이터/0727_Seoul_preprocessed.csv', encoding='cp949', index_col=0)
df
# Out:
#         기준_년_코드  기준_분기_코드   자치구     행정동  대분류      중분류    상권_코드 서비스_업종_코드  \
# 0          2022         4  영등포구    대림3동   소매  가구/인테리어  2120139  CS300031
# 1          2022         4   중랑구  면목3.8동   외식  카페/베이커리  2120068  CS100005
# 2          2022         4   강동구    천호3동   소매       의료  2130322  CS300018
# 3          2022         4   송파구     석촌동   소매    의류/잡화  2120230  CS300017
# 4          2022         4   송파구    가락본동  서비스       오락  2120234  CS200016
# ...         ...       ...   ...     ...  ...      ...      ...       ...
# 912344     2017         4   강남구    삼성1동   소매  가구/인테리어  1001496  CS300031
# 912345     2017         4   강남구    삼성1동   소매  가구/인테리어  1001496  CS300032
# 912346     2017         4   강남구    삼성1동   소매  가구/인테리어  1001496  CS300035
# 912347     2017         4   강남구    삼성1동   소매  가구/인테리어  1001496  CS300041
# 912348     2017         4   강남구    삼성1동   소매       유통  1001496  CS300043
#
#        서비스_업종_코드_명  점포_수  총_점포수  순점포증감률  개업_율  개업_점포_수  폐업_률  폐업_점포_수  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 912349 entries, 0 to 912348
# Data columns (total 23 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   기준_년_코드      912349 non-null  int64
#  1   기준_분기_코드     912349 non-null  int64
#  2   자치구          912349 non-null  object
#  3   행정동          912349 non-null  object
#  4   대분류          912349 non-null  object
#  5   중분류          912349 non-null  object
#  6   상권_코드        912349 non-null  int64
#  7   서비스_업종_코드    912349 non-null  object
#  8   서비스_업종_코드_명  912349 non-null  object
#  9   점포_수         912349 non-null  int64
#  10  총_점포수        912349 non-null  int64
#  11  순점포증감률       912346 non-null  float64
#  12  개업_율         912349 non-null  int64
#  13  개업_점포_수      912349 non-null  int64
#  14  폐업_률         912349 non-null  int64
#  15  폐업_점포_수      912349 non-null  int64
#  16  프랜차이즈_점포_수   912349 non-null  int64
#  17  총_매출_금액      912349 non-null  int64
# ...

# %%
import numpy as np
df.isnull().sum()
# Out:
# 기준_년_코드        0
# 기준_분기_코드       0
# 자치구            0
# 행정동            0
# 대분류            0
# 중분류            0
# 상권_코드          0
# 서비스_업종_코드      0
# 서비스_업종_코드_명    0
# 점포_수           0
# 총_점포수          0
# 순점포증감률         0
# 개업_율           0
# 개업_점포_수        0
# 폐업_률           0
# 폐업_점포_수        0
# 프랜차이즈_점포_수     0
# 총_매출_금액        0
# 분기당_매출_금액      0
# 주중_매출_금액       0
# 주말_매출_금액       0
# 남성_매출_금액       0
# 여성_매출_금액       0
# dtype: int64

# %%
# null 값이 있는 행 추출
df_with_null = df[df.isnull().any(axis=1)]
df_with_null
# Out:
#         기준_년_코드  기준_분기_코드  자치구     행정동  대분류  중분류    상권_코드 서비스_업종_코드  \
# 213155     2021         3  도봉구    방학3동   외식  식사류  2110386  CS100008
# 214382     2021         3  노원구  상계3.4동   외식  식사류  2110437  CS100002
# 666023     2018         3  강서구    방화2동  서비스   미용  2110633  CS200030
#
#        서비스_업종_코드_명  점포_수  총_점포수  순점포증감률  개업_율  개업_점포_수  폐업_률  폐업_점포_수  \
# 213155       분식전문점     0      0     NaN     0        1     0        1
# 214382       중식음식점     0      0     NaN     0        1     0        1
# 666023       피부관리실     0      0     NaN     0        1     0        1
#
#         프랜차이즈_점포_수   총_매출_금액  분기당_매출_금액  주중_매출_금액  주말_매출_금액  남성_매출_금액  \
# 213155           0   6396092    6396092   5568161    827931   2048682
# 214382           0  15000000   15000000   7861161   7138839   8840344
# 666023           0   4076642    4076642   3429991    646651   1535797
#
#         여성_매출_금액
# 213155   4210136
# 214382   6159656
# 666023   2540845

# %%
df_with_null.서비스_업종_코드_명.value_counts()
# Out:
# 분식전문점    1
# 중식음식점    1
# 피부관리실    1
# Name: 서비스_업종_코드_명, dtype: int64

# %%
df_with_null[df_with_null['서비스_업종_코드_명'] == '피부관리실']
# Out:
#         기준_년_코드  기준_분기_코드  자치구   행정동  대분류 중분류    상권_코드 서비스_업종_코드 서비스_업종_코드_명  \
# 666023     2018         3  강서구  방화2동  서비스  미용  2110633  CS200030       피부관리실
#
#         점포_수  총_점포수  순점포증감률  개업_율  개업_점포_수  폐업_률  폐업_점포_수  프랜차이즈_점포_수  \
# 666023     0      0     NaN     0        1     0        1           0
#
#         총_매출_금액  분기당_매출_금액  주중_매출_금액  주말_매출_금액  남성_매출_금액  여성_매출_금액
# 666023  4076642    4076642   3429991    646651   1535797   2540845

# %%
# len(df[df['서비스_업종_코드_명'] == '피부관리실'])

# %%
df.loc[666023, '순점포증감률']
# Out:
# nan

# %%
df[df['순점포증감률'].isna()]
# Out:
#         기준_년_코드  기준_분기_코드  자치구     행정동  대분류  중분류    상권_코드 서비스_업종_코드  \
# 213155     2021         3  도봉구    방학3동   외식  식사류  2110386  CS100008
# 214382     2021         3  노원구  상계3.4동   외식  식사류  2110437  CS100002
# 666023     2018         3  강서구    방화2동  서비스   미용  2110633  CS200030
#
#        서비스_업종_코드_명  점포_수  총_점포수  순점포증감률  개업_율  개업_점포_수  폐업_률  폐업_점포_수  \
# 213155       분식전문점     0      0     NaN     0        1     0        1
# 214382       중식음식점     0      0     NaN     0        1     0        1
# 666023       피부관리실     0      0     NaN     0        1     0        1
#
#         프랜차이즈_점포_수   총_매출_금액  분기당_매출_금액  주중_매출_금액  주말_매출_금액  남성_매출_금액  \
# 213155           0   6396092    6396092   5568161    827931   2048682
# 214382           0  15000000   15000000   7861161   7138839   8840344
# 666023           0   4076642    4076642   3429991    646651   1535797
#
#         여성_매출_금액
# 213155   4210136
# 214382   6159656
# 666023   2540845

# %%
# '순점포증감률' 열의 NaN 값을 0으로 변경
df['순점포증감률'] = df['순점포증감률'].fillna(0)
df[df['순점포증감률'].isna()]
# Out:
# Empty DataFrame
# Columns: [기준_년_코드, 기준_분기_코드, 자치구, 행정동, 대분류, 중분류, 상권_코드, 서비스_업종_코드, 서비스_업종_코드_명, 점포_수, 총_점포수, 순점포증감률, 개업_율, 개업_점포_수, 폐업_률, 폐업_점포_수, 프랜차이즈_점포_수, 총_매출_금액, 분기당_매출_금액, 주중_매출_금액, 주말_매출_금액, 남성_매출_금액, 여성_매출_금액]
# Index: []

# %%
df.isnull().sum()
# Out:
# 기준_년_코드        0
# 기준_분기_코드       0
# 자치구            0
# 행정동            0
# 대분류            0
# 중분류            0
# 상권_코드          0
# 서비스_업종_코드      0
# 서비스_업종_코드_명    0
# 점포_수           0
# 총_점포수          0
# 순점포증감률         0
# 개업_율           0
# 개업_점포_수        0
# 폐업_률           0
# 폐업_점포_수        0
# 프랜차이즈_점포_수     0
# 총_매출_금액        0
# 분기당_매출_금액      0
# 주중_매출_금액       0
# 주말_매출_금액       0
# 남성_매출_금액       0
# 여성_매출_금액       0
# dtype: int64

# %%
# df.to_csv('/content/drive/MyDrive/MC_KDT/프로젝트/파이널프로젝트/데이터/0727_Seoul_preprocessed.csv', encoding='euc-kr')

# %%
double_check = pd.read_csv('/content/drive/MyDrive/MC_KDT/프로젝트/파이널프로젝트/데이터/0727_Seoul_preprocessed.csv', encoding='cp949', index_col=0)
double_check
# Out:
#         기준_년_코드  기준_분기_코드   자치구     행정동  대분류      중분류    상권_코드 서비스_업종_코드  \
# 0          2022         4  영등포구    대림3동   소매  가구/인테리어  2120139  CS300031
# 1          2022         4   중랑구  면목3.8동   외식  카페/베이커리  2120068  CS100005
# 2          2022         4   강동구    천호3동   소매       의료  2130322  CS300018
# 3          2022         4   송파구     석촌동   소매    의류/잡화  2120230  CS300017
# 4          2022         4   송파구    가락본동  서비스       오락  2120234  CS200016
# ...         ...       ...   ...     ...  ...      ...      ...       ...
# 912344     2017         4   강남구    삼성1동   소매  가구/인테리어  1001496  CS300031
# 912345     2017         4   강남구    삼성1동   소매  가구/인테리어  1001496  CS300032
# 912346     2017         4   강남구    삼성1동   소매  가구/인테리어  1001496  CS300035
# 912347     2017         4   강남구    삼성1동   소매  가구/인테리어  1001496  CS300041
# 912348     2017         4   강남구    삼성1동   소매       유통  1001496  CS300043
#
#        서비스_업종_코드_명  점포_수  총_점포수  순점포증감률  개업_율  개업_점포_수  폐업_률  폐업_점포_수  \
# ...

# %%
double_check.isnull().sum()
# Out:
# 기준_년_코드        0
# 기준_분기_코드       0
# 자치구            0
# 행정동            0
# 대분류            0
# 중분류            0
# 상권_코드          0
# 서비스_업종_코드      0
# 서비스_업종_코드_명    0
# 점포_수           0
# 총_점포수          0
# 순점포증감률         0
# 개업_율           0
# 개업_점포_수        0
# 폐업_률           0
# 폐업_점포_수        0
# 프랜차이즈_점포_수     0
# 총_매출_금액        0
# 분기당_매출_금액      0
# 주중_매출_금액       0
# 주말_매출_금액       0
# 남성_매출_금액       0
# 여성_매출_금액       0
# dtype: int64

# %% [markdown]
# # "스포츠강습" 띄어쓰기 처리

# %%
df = pd.read_csv('/content/drive/MyDrive/MC_KDT/프로젝트/파이널프로젝트/데이터/0727_Seoul_preprocessed.csv', encoding='cp949', index_col=0)
df
# Out:
#         기준_년_코드  기준_분기_코드   자치구     행정동  대분류      중분류    상권_코드 서비스_업종_코드  \
# 0          2022         4  영등포구    대림3동   소매  가구/인테리어  2120139  CS300031
# 1          2022         4   중랑구  면목3.8동   외식  카페/베이커리  2120068  CS100005
# 2          2022         4   강동구    천호3동   소매       의료  2130322  CS300018
# 3          2022         4   송파구     석촌동   소매    의류/잡화  2120230  CS300017
# 4          2022         4   송파구    가락본동  서비스       오락  2120234  CS200016
# ...         ...       ...   ...     ...  ...      ...      ...       ...
# 912344     2017         4   강남구    삼성1동   소매  가구/인테리어  1001496  CS300031
# 912345     2017         4   강남구    삼성1동   소매  가구/인테리어  1001496  CS300032
# 912346     2017         4   강남구    삼성1동   소매  가구/인테리어  1001496  CS300035
# 912347     2017         4   강남구    삼성1동   소매  가구/인테리어  1001496  CS300041
# 912348     2017         4   강남구    삼성1동   소매       유통  1001496  CS300043
#
#        서비스_업종_코드_명  점포_수  총_점포수  순점포증감률  개업_율  개업_점포_수  폐업_률  폐업_점포_수  \
# ...

# %%
df[df['서비스_업종_코드_명'] == '스포츠강습']
# Out:
# Empty DataFrame
# Columns: [기준_년_코드, 기준_분기_코드, 자치구, 행정동, 대분류, 중분류, 상권_코드, 서비스_업종_코드, 서비스_업종_코드_명, 점포_수, 총_점포수, 순점포증감률, 개업_율, 개업_점포_수, 폐업_률, 폐업_점포_수, 프랜차이즈_점포_수, 총_매출_금액, 분기당_매출_금액, 주중_매출_금액, 주말_매출_금액, 남성_매출_금액, 여성_매출_금액]
# Index: []

# %%
df.서비스_업종_코드_명.unique()
# Out:
# array(['가구', '제과점', '의약품', '시계및귀금속', '당구장', '중식음식점', '노래방', '패스트푸드점',
#        '여관', '신발', '한의원', '자동차수리', '애완동물', '외국어학원', 'PC방', '예술학원', '화초',
#        '치킨전문점', '고시원', '안경', '스포츠 강습', '핸드폰', '편의점', '문구', '치과의원',
#        '스포츠클럽', '섬유제품', '미용실', '분식전문점', '운동/경기용품', '일반의원', '일식음식점',
#        '반찬가게', '피부관리실', '인테리어', '완구', '철물점', '일반교습학원', '양식음식점', '일반의류',
#        '컴퓨터및주변장치판매', '서적', '전자상거래업', '슈퍼마켓', '부동산중개업', '호프-간이주점', '한식음식점',
#        '세탁소', '화장품', '조명용품', '골프연습장', '가전제품', '커피-음료', '미곡판매', '청과상',
#        '수산물판매', '육류판매', '자동차미용', '의료기기', '가전제품수리', '가방', '네일숍',
#        '자전거 및 기타운송장비', '예술품', '여행사', '주유소', '독서실', '사진관', '한복점', '악기',
#        '회계사사무소', '세무사사무소', '유아의류', '자동차부품', '볼링장', '통신기기수리', '중고차판매',
#        '비디오/서적임대', '법무사사무소', '변호사사무소', '건축물청소'], dtype=object)

# %%
df['서비스_업종_코드_명'] = df['서비스_업종_코드_명'].replace('스포츠 강습', '스포츠강습')
df[df['서비스_업종_코드_명'] == '스포츠 강습']
# Out:
# Empty DataFrame
# Columns: [기준_년_코드, 기준_분기_코드, 자치구, 행정동, 대분류, 중분류, 상권_코드, 서비스_업종_코드, 서비스_업종_코드_명, 점포_수, 총_점포수, 순점포증감률, 개업_율, 개업_점포_수, 폐업_률, 폐업_점포_수, 프랜차이즈_점포_수, 총_매출_금액, 분기당_매출_금액, 주중_매출_금액, 주말_매출_금액, 남성_매출_금액, 여성_매출_금액]
# Index: []

# %%
df[df['서비스_업종_코드_명'] == '스포츠강습']
# Out:
#         기준_년_코드  기준_분기_코드  자치구          행정동  대분류 중분류    상권_코드 서비스_업종_코드  \
# 21         2022         4   중구          청구동  서비스  교육  2110054  CS200005
# 75         2022         4  광진구         자양4동  서비스  교육  2110140  CS200005
# 182        2022         4  강남구         대치2동  서비스  교육  2120222  CS200005
# 190        2022         4  금천구          가산동  서비스  교육  2120131  CS200005
# 201        2022         4  송파구         잠실본동  서비스  교육  2120225  CS200005
# ...         ...       ...  ...          ...  ...  ..      ...       ...
# 912017     2017         4  용산구        이태원1동  서비스  교육  1001491  CS200005
# 912075     2017         4   중구          소공동  서비스  교육  1001492  CS200005
# 912139     2017         4   중구          광희동  서비스  교육  1001493  CS200005
# 912200     2017         4  종로구  종로1.2.3.4가동  서비스  교육  1001494  CS200005
# 912265     2017         4  송파구          오륜동  서비스  교육  1001495  CS200005
#
#        서비스_업종_코드_명  점포_수  총_점포수    순점포증감률  개업_율  개업_점포_수  폐업_률  폐업_점포_수  \
# ...

# %%
df.columns
# Out:
# Index(['기준_년_코드', '기준_분기_코드', '자치구', '행정동', '대분류', '중분류', '상권_코드', '서비스_업종_코드',
#        '서비스_업종_코드_명', '점포_수', '총_점포수', '순점포증감률', '개업_율', '개업_점포_수', '폐업_률',
#        '폐업_점포_수', '프랜차이즈_점포_수', '총_매출_금액', '분기당_매출_금액', '주중_매출_금액', '주말_매출_금액',
#        '남성_매출_금액', '여성_매출_금액'],
#       dtype='object')

# %%
# 컬럼명 변경
df = df.rename(columns = {'서비스_업종_코드_명':'업종명'})

# %%
df.columns
# Out:
# Index(['기준_년_코드', '기준_분기_코드', '자치구', '행정동', '대분류', '중분류', '상권_코드', '서비스_업종_코드',
#        '업종명', '점포_수', '총_점포수', '순점포증감률', '개업_율', '개업_점포_수', '폐업_률', '폐업_점포_수',
#        '프랜차이즈_점포_수', '총_매출_금액', '분기당_매출_금액', '주중_매출_금액', '주말_매출_금액',
#        '남성_매출_금액', '여성_매출_금액'],
#       dtype='object')

# %%
# 필요한 컬럼만 추출
df = df[['기준_년_코드', '기준_분기_코드', '자치구', '행정동', '대분류', '상권_코드', '중분류', '업종명', '총_점포수', '점포_수', '순점포증감률', '개업_율', '개업_점포_수', '폐업_률',
         '폐업_점포_수', '프랜차이즈_점포_수', '총_매출_금액', '분기당_매출_금액', '주중_매출_금액', '주말_매출_금액', '남성_매출_금액', '여성_매출_금액']]
print(df.shape)
df.head(2)
# Out:
# (912349, 22)
#    기준_년_코드  기준_분기_코드   자치구     행정동 대분류    상권_코드      중분류  업종명  총_점포수  점포_수  \
# 0     2022         4  영등포구    대림3동  소매  2120139  가구/인테리어   가구      2     2
# 1     2022         4   중랑구  면목3.8동  외식  2120068  카페/베이커리  제과점      5     3
#
#    순점포증감률  개업_율  개업_점포_수  폐업_률  폐업_점포_수  프랜차이즈_점포_수     총_매출_금액   분기당_매출_금액  \
# 0     0.0     0        0     0        0           0   205619535   205619535
# 1     0.2    20        1     0        0           2  1111094837  1111094837
#
#     주중_매출_금액   주말_매출_금액   남성_매출_금액   여성_매출_금액
# 0  205619535          0   12549549  193069986
# 1  759670537  351424300  405775472  623495718

# %%
df.isnull().sum()
# Out:
# 기준_년_코드       0
# 기준_분기_코드      0
# 자치구           0
# 행정동           0
# 대분류           0
# 상권_코드         0
# 중분류           0
# 업종명           0
# 총_점포수         0
# 점포_수          0
# 순점포증감률        0
# 개업_율          0
# 개업_점포_수       0
# 폐업_률          0
# 폐업_점포_수       0
# 프랜차이즈_점포_수    0
# 총_매출_금액       0
# 분기당_매출_금액     0
# 주중_매출_금액      0
# 주말_매출_금액      0
# 남성_매출_금액      0
# 여성_매출_금액      0
# dtype: int64

# %%
# df.to_csv('/content/drive/MyDrive/MC_KDT/프로젝트/파이널프로젝트/데이터/0727_Seoul_preprocessed.csv', encoding='euc-kr')

# %% [markdown]
# # 전처리 최종_컬럼 순서 바꾸기

# %%
df = pd.read_csv('/content/drive/MyDrive/MC_KDT/프로젝트/파이널프로젝트/데이터/0727_Seoul_preprocessed.csv', encoding='cp949', index_col=0)
df
# Out:
#         기준_년_코드  기준_분기_코드   자치구    행정동  대분류    상권_코드      중분류         업종명  \
# 101760     2022         1  서대문구  북가좌2동  서비스  2110499       의료         한의원
# 101761     2022         1   노원구   공릉1동   소매  2110433    의류/잡화          안경
# 101762     2022         1   마포구   성산1동   소매  2110548     전자기기  컴퓨터및주변장치판매
# 101763     2022         1   은평구    대조동  서비스  2110481       미용       피부관리실
# 101764     2022         1  영등포구   신길6동  서비스  2110804       교육        예술학원
# ...         ...       ...   ...    ...  ...      ...      ...         ...
# 912344     2017         4   강남구   삼성1동   소매  1001496  가구/인테리어          가구
# 912345     2017         4   강남구   삼성1동   소매  1001496  가구/인테리어        가전제품
# 912346     2017         4   강남구   삼성1동   소매  1001496  가구/인테리어        인테리어
# 912347     2017         4   강남구   삼성1동   소매  1001496  가구/인테리어         예술품
# 912348     2017         4   강남구   삼성1동   소매  1001496       유통      전자상거래업
#
#         총_점포수  점포_수    순점포증감률  개업_율  개업_점포_수  폐업_률  폐업_점포_수  프랜차이즈_점포_수  \
# ...

# %%
new_df = df.copy()
df_sorted = new_df.sort_values(by=['기준_년_코드', '기준_분기_코드'], ascending=[False, True])
df_sorted.reset_index(drop=True, inplace=True)

df_sorted
# Out:
#         기준_년_코드  기준_분기_코드   자치구    행정동  대분류    상권_코드      중분류         업종명  \
# 0          2022         1  서대문구  북가좌2동  서비스  2110499       의료         한의원
# 1          2022         1   노원구   공릉1동   소매  2110433    의류/잡화          안경
# 2          2022         1   마포구   성산1동   소매  2110548     전자기기  컴퓨터및주변장치판매
# 3          2022         1   은평구    대조동  서비스  2110481       미용       피부관리실
# 4          2022         1  영등포구   신길6동  서비스  2110804       교육        예술학원
# ...         ...       ...   ...    ...  ...      ...      ...         ...
# 912344     2017         4   강남구   삼성1동   소매  1001496  가구/인테리어          가구
# 912345     2017         4   강남구   삼성1동   소매  1001496  가구/인테리어        가전제품
# 912346     2017         4   강남구   삼성1동   소매  1001496  가구/인테리어        인테리어
# 912347     2017         4   강남구   삼성1동   소매  1001496  가구/인테리어         예술품
# 912348     2017         4   강남구   삼성1동   소매  1001496       유통      전자상거래업
#
#         총_점포수  점포_수    순점포증감률  개업_율  개업_점포_수  폐업_률  폐업_점포_수  프랜차이즈_점포_수  \
# ...

# %% [markdown]
# # 파일 저장

# %%
# df_sorted.to_csv('/content/drive/MyDrive/MC_KDT/프로젝트/파이널프로젝트/데이터/0727_Seoul_preprocessed.csv', encoding='euc-kr')
