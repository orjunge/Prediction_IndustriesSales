# %%
from IPython.display import Image, display

# %% [markdown]
# # 추천 비추천 업종

# %%
display(Image(filename="추천비추천.png", width=1000, height=700))

# %% [markdown]
# # 가설 검증

# %% [markdown]
# ## 압구정동
#
# > 귀무가설 채택

# %%
display(Image(filename="압구정가설.png", width=1000, height=700))

# %% [markdown]
# ## 신촌동
#
# > 귀무가설 기각, 대립가설 채택

# %%
display(Image(filename="신촌동가설.png", width=1000, height=700))
